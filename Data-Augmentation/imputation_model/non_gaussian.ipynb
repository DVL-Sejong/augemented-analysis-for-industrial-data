# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./saches.csv')

# %%
df
# Out:
#       Unnamed: 0  praf   pmek   plcg    PIP2   PIP3  p44/42  pakts473     PKA  \
# 0              0  26.4  13.20   8.82   18.30  58.80    6.61      17.0   414.0
# 1              1  35.9  16.50  12.30   16.80   8.13   18.60      32.5   352.0
# 2              2  59.4  44.10  14.60   10.20  13.00   14.90      32.5   403.0
# 3              3  73.0  82.80  23.10   13.50   1.29    5.83      11.8   528.0
# 4              4  33.7  19.80   5.19    9.73  24.80   21.10      46.1   305.0
# ...          ...   ...    ...    ...     ...    ...     ...       ...     ...
# 7461        7461  49.1  12.40  32.80   27.90  22.70   11.70      38.2  1144.0
# 7462        7462  23.3   4.61  17.80   22.10  14.90   48.70      67.3   922.0
# 7463        7463  28.1   4.49  18.80   20.20  10.20    3.08      21.9   730.0
# 7464        7464  34.6   7.10   5.73   20.70  15.10   32.20      41.4   813.0
# 7465        7465  30.5   1.01   7.30  173.00  22.90    6.61      13.7   890.0
#
#         PKC      P38   pjnk
# 0     17.00    44.90  40.00
# 1      3.37    16.50  61.50
# 2     11.40    31.90  19.50
# 3     13.70    28.60  23.10
# 4      4.66    25.70  81.30
# ...     ...      ...    ...
# 7461   1.00     2.55   1.00
# 7462   1.00     9.82   1.00
# 7463   1.00     1.75   2.00
# 7464  44.50  1382.00   2.44
# 7465   1.00     1.00   1.65
#
# [7466 rows x 12 columns]

# %%
from scipy.stats import shapiro
_, p_value = shapiro(df['praf'])
# Out:
# c:\Users\chanyoung\anaconda3\envs\coolingts\lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
from scipy.stats import anderson
result = anderson(df['praf'])

# %%
result.statistic
# Out:
# 1339.6270411843434

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

sm.qqplot(df['praf'], line='s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import statsmodels.api as sm
#       2 import matplotlib.pyplot as plt
#       4 sm.qqplot(df['praf'], line='s')
#
# ModuleNotFoundError: No module named 'statsmodels'
