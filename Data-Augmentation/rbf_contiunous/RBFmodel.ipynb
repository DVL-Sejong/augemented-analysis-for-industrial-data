# %%
import torch
import pandas as pd
import numpy as np

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
df = pd.read_csv("../dataset/pm25_missing.txt").drop(['datetime'], axis = 1)[:1000]
df = df.reset_index(drop=True)
target = torch.tensor(df.values).T.to(device).reshape(36,len(df))
input = torch.tensor(df.index + 1, dtype=float).to(device)

# %%
df = pd.read_csv("./RBFresult/air_20_8.0_drop_0.2.csv")

# %%
df
# Out:
#           001001      001002      001003      001004      001005      001006  \
# 0     138.793088   81.997635  107.443393  100.832155  111.010475   90.495579
# 1     142.480859   93.450936  120.756462  110.588532  112.872475  101.796595
# 2     140.322823   99.216947  134.837385  117.398488  107.544021  109.724747
# 3     136.200119  104.716287  143.196925  121.999474  106.184107  116.756154
# 4     127.655348  119.077525  140.440733  118.974420  115.701420  124.872454
# ...          ...         ...         ...         ...         ...         ...
# 8754   92.123441   71.400853   69.237157   71.182906   71.943053   62.124311
# 8755   88.829187   66.079334   69.951633   71.420826   76.387368   63.513600
# 8756   85.046936   62.702462   73.913321   74.306048   82.478074   68.024392
# 8757   81.421181   66.205696   78.889170   75.728640   83.396289   70.232094
# 8758   78.459770   72.666887   88.040437   76.229564   80.064193   71.684268
#
# ...
