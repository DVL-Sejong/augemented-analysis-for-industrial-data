# %%
import pandas as pd
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
data_df = pd.read_csv('C:/Users/chanyoung/Desktop/RBFfitting/data/sangiovese/sangiovese100.csv')
data_df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data_df
# Out:
#      SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0  -0.346184 -0.528339 -0.863465 -0.617428 -0.106392  0.050823 -0.198278
# 1  -0.153031 -0.400980 -0.363443  0.206970  0.006421  0.194551  0.044448
# 2  -0.030385  0.015431  0.840254 -0.279058  0.000163  0.105888  0.089827
# 3  -0.100034 -0.836594 -0.620349  0.063581  0.046857  0.007490  0.115941
# 4  -0.021382  0.200724 -0.249094 -0.370807 -0.137172 -0.190638 -0.170088
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.177467 -0.644153 -0.450410 -0.286729 -0.127522  0.016486 -0.156260
# 96 -0.130045 -0.095489  0.437092  0.352160  0.000715 -0.198517  0.112071
# 97  0.033313  0.382636  0.390776 -0.418563 -0.108692 -0.102805 -0.034051
# 98  0.094404  0.150532  0.557996  0.537552  0.197651  0.060792  0.185354
# 99 -0.058529  0.234550  0.171101 -0.459576 -0.055019 -0.046831 -0.216748
#
#       NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0   0.045205  0.037551 -0.001210  0.104539 -0.038003  0.499180  0.251336
# 1   0.003382  0.002642 -0.296872  0.003218  0.009141 -0.008537 -0.238323
# 2  -0.064657 -0.091271  0.069681 -0.104757  0.008554 -0.288625 -0.096597
# 3   0.109238  0.004422  0.349025 -0.044265  0.030596 -0.503229 -0.092977
# 4  -0.002560  0.085651  0.056391 -0.043244 -0.006474  0.308487  0.235036
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.085801  0.019791  0.239494  0.061734 -0.007895  0.401038  0.152107
# 96 -0.069501 -0.010863  0.014541 -0.085919 -0.011254 -0.282974 -0.193205
# 97 -0.018838 -0.047526 -0.087722  0.008296 -0.019963  0.094318 -0.037053
# 98  0.184256  0.102725 -0.275379  0.018454 -0.020639  0.016230  0.178246
# 99 -0.155764  0.252314 -0.264366 -0.174633 -0.058274 -0.209883 -0.356365
#
# [100 rows x 14 columns]

# %%
a = list()
for col in data_df.columns:
    y = data_df[col].values
    x = np.array(list(data_df.index), dtype = float)
    xnew = np.arange(0,99, 0.5)
    f_quadr = interpolate.BSpline(x, y, k=2)
    y_new_quadr = f_quadr(xnew)
    a.append([y_new_quadr])
new_df = pd.DataFrame(np.concatenate(a).T, columns = data_df.columns)
new_df
# Out:
#       SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0   -0.776926 -0.141274 -0.206151 -4.474875 -0.513758 -0.629553 -0.957063
# 1   -0.618657 -0.330515 -0.571854 -2.916054 -0.353162 -0.354346 -0.663021
# 2   -0.478014 -0.447493 -0.761639 -1.684839 -0.222335 -0.137237 -0.418315
# 3   -0.354997 -0.492208 -0.775506 -0.781231 -0.121276  0.021774 -0.222947
# 4   -0.249608 -0.464660 -0.613454 -0.205229 -0.049985  0.122687 -0.076915
# ..        ...       ...       ...       ...       ...       ...       ...
# 193 -0.194297 -0.543764 -0.428192 -0.306052 -0.106108 -0.023411 -0.129512
# 194 -0.153756 -0.369821 -0.006659  0.032716 -0.063403 -0.091016 -0.022095
# 195 -0.146875  0.004900  0.459309  0.332837  0.022129 -0.238414  0.138819
# 196 -0.173655  0.580397  0.969713  0.594311  0.150489 -0.465607  0.353227
# 197 -0.234096  1.356670  1.524551  0.817139  0.321676 -0.772594  0.621131
#
#        NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0    0.055503 -0.028091  1.766716  0.243216 -0.204180  1.716017  2.248593
# 1    0.057532  0.006082  1.039446  0.198376 -0.138844  1.262982  1.451302
# 2    0.053007  0.025504  0.477730  0.151873 -0.085440  0.866854  0.811858
# 3    0.041928  0.030176  0.081567  0.103707 -0.043969  0.527634  0.330259
# 4    0.024294  0.020096 -0.149041  0.053878 -0.014431  0.245322  0.006507
# ..        ...       ...       ...       ...       ...       ...       ...
# 193  0.037554  0.022033  0.201500  0.042037 -0.012651  0.364129  0.127025
# 194  0.008150  0.004464  0.127017 -0.012093 -0.009575  0.059032 -0.020549
# 195 -0.117748 -0.008620 -0.023453 -0.105616 -0.016010 -0.319883 -0.218287
# 196 -0.340140 -0.017219 -0.249911 -0.238532 -0.031958 -0.772616 -0.466188
# 197 -0.659025 -0.021332 -0.552356 -0.410843 -0.057418 -1.299166 -0.764253
#
# [198 rows x 14 columns]

# %%
new_df.to_csv('./data/poly_sang_200.csv', index = False)

# %%
a = list()
for col in data_df.columns:
    y = data_df[col].values
    x = np.array(list(data_df.index), dtype = float)
    xnew = np.arange(0,99, 0.25)
    f_quadr = interpolate.BSpline(x, y, k=2)
    y_new_quadr = f_quadr(xnew)
    a.append([y_new_quadr])
new_df = pd.DataFrame(np.concatenate(a).T, columns = data_df.columns)
new_df
# Out:
#       SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0   -0.776926 -0.141274 -0.206151 -4.474875 -0.513758 -0.629553 -0.957063
# 1   -0.695588 -0.244928 -0.410992 -3.654514 -0.429739 -0.484687 -0.803874
# 2   -0.618657 -0.330515 -0.571854 -2.916054 -0.353162 -0.354346 -0.663021
# 3   -0.546132 -0.398037 -0.688737 -2.259496 -0.284028 -0.238529 -0.534501
# 4   -0.478014 -0.447493 -0.761639 -1.684839 -0.222335 -0.137237 -0.418315
# ..        ...       ...       ...       ...       ...       ...       ...
# 391 -0.156057  0.267551  0.708957  0.468405  0.080955 -0.342037  0.239336
# 392 -0.173655  0.580397  0.969713  0.594311  0.150489 -0.465607  0.353227
# 393 -0.199668  0.943436  1.241577  0.710556  0.230729 -0.609127  0.480492
# 394 -0.234096  1.356670  1.524551  0.817139  0.321676 -0.772594  0.621131
# 395 -0.276939  1.820099  1.818633  0.914061  0.423330 -0.956011  0.775143
#
#        NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0    0.055503 -0.028091  1.766716  0.243216 -0.204180  1.716017  2.248593
# 1    0.057337 -0.009161  1.382387  0.221004 -0.170021  1.482386  1.830217
# 2    0.057532  0.006082  1.039446  0.198376 -0.138844  1.262982  1.451302
# 3    0.056089  0.017637  0.737893  0.175333 -0.110650  1.057805  1.111849
# 4    0.053007  0.025504  0.477730  0.151873 -0.085440  0.866854  0.811858
# ..        ...       ...       ...       ...       ...       ...       ...
# 391 -0.216882 -0.013480 -0.127183 -0.167150 -0.022795 -0.537022 -0.335967
# 392 -0.340140 -0.017219 -0.249911 -0.238532 -0.031958 -0.772616 -0.466188
# 393 -0.487521 -0.019836 -0.391635 -0.319763 -0.043499 -1.026664 -0.608950
# 394 -0.659025 -0.021332 -0.552356 -0.410843 -0.057418 -1.299166 -0.764253
# 395 -0.854653 -0.021706 -0.732074 -0.511770 -0.073715 -1.590123 -0.932098
#
# [396 rows x 14 columns]

# %%
new_df.to_csv('./data/poly_sang_400.csv', index = False)

# %%
a = list()
for col in data_df.columns:
    y = data_df[col].values
    x = np.array(list(data_df.index), dtype = float)
    xnew = np.arange(0,99, 0.1)
    f_quadr = interpolate.BSpline(x, y, k=2)
    y_new_quadr = f_quadr(xnew)
    a.append([y_new_quadr])
new_df = pd.DataFrame(np.concatenate(a).T, columns = data_df.columns)
new_df
# Out:
#       SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0   -0.776926 -0.141274 -0.206151 -4.474875 -0.513758 -0.629553 -0.957063
# 1   -0.743862 -0.184903 -0.293365 -4.136902 -0.479257 -0.569864 -0.894307
# 2   -0.711503 -0.225642 -0.373542 -3.812034 -0.445947 -0.512499 -0.833525
# 3   -0.679849 -0.263490 -0.446683 -3.500269 -0.413828 -0.457457 -0.774717
# 4   -0.648901 -0.298448 -0.512787 -3.201610 -0.382900 -0.404740 -0.717882
# ..        ...       ...       ...       ...       ...       ...       ...
# 985 -0.234096  1.356670  1.524551  0.817139  0.321676 -0.772594  0.621131
# 986 -0.250223  1.536018  1.640851  0.857067  0.361053 -0.843567  0.681131
# 987 -0.267697  1.723398  1.758928  0.895450  0.402143 -0.917732  0.743271
# 988 -0.286518  1.918808  1.878782  0.932286  0.444946 -0.995088  0.807550
# 989 -0.306684  2.122249  2.000415  0.967576  0.489462 -1.075636  0.873970
#
#        NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0    0.055503 -0.028091  1.766716  0.243216 -0.204180  1.716017  2.248593
# 1    0.056433 -0.020076  1.608018  0.234381 -0.190159  1.620857  2.076507
# 2    0.057101 -0.012652  1.455941  0.225479 -0.176614  1.527974  1.910735
# 3    0.057507 -0.005817  1.310487  0.216512 -0.163547  1.437367  1.751277
# 4    0.057651  0.000428  1.171656  0.207477 -0.150957  1.349036  1.598133
# ..        ...       ...       ...       ...       ...       ...       ...
# 985 -0.659025 -0.021332 -0.552356 -0.410843 -0.057418 -1.299166 -0.764253
# 986 -0.734382 -0.021616 -0.621964 -0.450032 -0.063651 -1.413335 -0.829886
# 987 -0.813598 -0.021721 -0.694611 -0.490797 -0.070265 -1.530456 -0.897525
# 988 -0.896674 -0.021646 -0.770297 -0.533138 -0.077259 -1.650529 -0.967171
# 989 -0.983609 -0.021392 -0.849023 -0.577054 -0.084634 -1.773556 -1.038824
#
# [990 rows x 14 columns]

# %%
new_df.to_csv('./data/poly_sang_1000.csv', index = False)
