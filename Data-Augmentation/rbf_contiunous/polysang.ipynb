# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv('C:/Users/chanyoung/Desktop/RBFfitting/data/sangiovese/sangiovese100.csv')
data_df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data_df
# Out:
#      SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0  -0.346184 -0.528339 -0.863465 -0.617428 -0.106392  0.050823 -0.198278
# 1  -0.153031 -0.400980 -0.363443  0.206970  0.006421  0.194551  0.044448
# 2  -0.030385  0.015431  0.840254 -0.279058  0.000163  0.105888  0.089827
# 3  -0.100034 -0.836594 -0.620349  0.063581  0.046857  0.007490  0.115941
# 4  -0.021382  0.200724 -0.249094 -0.370807 -0.137172 -0.190638 -0.170088
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.177467 -0.644153 -0.450410 -0.286729 -0.127522  0.016486 -0.156260
# 96 -0.130045 -0.095489  0.437092  0.352160  0.000715 -0.198517  0.112071
# 97  0.033313  0.382636  0.390776 -0.418563 -0.108692 -0.102805 -0.034051
# 98  0.094404  0.150532  0.557996  0.537552  0.197651  0.060792  0.185354
# 99 -0.058529  0.234550  0.171101 -0.459576 -0.055019 -0.046831 -0.216748
#
#       NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0   0.045205  0.037551 -0.001210  0.104539 -0.038003  0.499180  0.251336
# 1   0.003382  0.002642 -0.296872  0.003218  0.009141 -0.008537 -0.238323
# 2  -0.064657 -0.091271  0.069681 -0.104757  0.008554 -0.288625 -0.096597
# 3   0.109238  0.004422  0.349025 -0.044265  0.030596 -0.503229 -0.092977
# 4  -0.002560  0.085651  0.056391 -0.043244 -0.006474  0.308487  0.235036
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.085801  0.019791  0.239494  0.061734 -0.007895  0.401038  0.152107
# 96 -0.069501 -0.010863  0.014541 -0.085919 -0.011254 -0.282974 -0.193205
# 97 -0.018838 -0.047526 -0.087722  0.008296 -0.019963  0.094318 -0.037053
# 98  0.184256  0.102725 -0.275379  0.018454 -0.020639  0.016230  0.178246
# 99 -0.155764  0.252314 -0.264366 -0.174633 -0.058274 -0.209883 -0.356365
#
# [100 rows x 14 columns]

# %%
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
a = list()
for col in data_df.columns:
    y = data_df[col].values
    x = np.array(list(data_df.index), dtype = float)
    xnew = np.arange(0,99, 0.5)
    f_quadr = interpolate.interp1d(x, y, kind='quadratic')
    y_new_quadr = f_quadr(xnew)
    a.append([y_new_quadr])
new_df = pd.DataFrame(np.concatenate(a).T, columns = data_df.columns)
new_df
# Out:
#       SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0   -0.346184 -0.528339 -0.863465 -0.617428 -0.106392  0.050823 -0.198278
# 1   -0.244828 -0.548464 -0.791906  0.011113 -0.029934  0.157138 -0.046761
# 2   -0.153031 -0.400980 -0.363443  0.206970  0.006421  0.194551  0.044448
# 3   -0.070796 -0.085889  0.421925 -0.029857  0.002673  0.163063  0.075349
# 4   -0.030385  0.015431  0.840254 -0.279058  0.000163  0.105888  0.089827
# ..        ...       ...       ...       ...       ...       ...       ...
# 193 -0.054483  0.213286  0.458951 -0.083118 -0.070615 -0.186063  0.038186
# 194  0.033313  0.382636  0.390776 -0.418563 -0.108692 -0.102805 -0.034051
# 195  0.086551  0.298354  0.480195  0.030832  0.043613 -0.004795  0.080103
# 196  0.094404  0.150532  0.557996  0.537552  0.197651  0.060792  0.185354
# 197  0.046044  0.129264  0.454964  0.374083  0.164774  0.046780  0.086404
#
#        NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0    0.045205  0.037551 -0.001210  0.104539 -0.038003  0.499180  0.251336
# 1    0.035407  0.033537 -0.245564  0.059306 -0.006623  0.209089 -0.090979
# 2    0.003382  0.002642 -0.296872  0.003218  0.009141 -0.008537 -0.238323
# 3   -0.050870 -0.055136 -0.155134 -0.063725  0.009290 -0.153700 -0.190696
# 4   -0.064657 -0.091271  0.069681 -0.104757  0.008554 -0.288625 -0.096597
# ..        ...       ...       ...       ...       ...       ...       ...
# 193 -0.081632 -0.041618 -0.040957 -0.054513 -0.016920 -0.141273 -0.165857
# 194 -0.018838 -0.047526 -0.087722  0.008296 -0.019963  0.094318 -0.037053
# 195  0.107818  0.013338 -0.184932  0.035518 -0.018604  0.112447  0.118442
# 196  0.184256  0.102725 -0.275379  0.018454 -0.020639  0.016230  0.178246
# 197  0.096395  0.182383 -0.301857 -0.051596 -0.033862 -0.091213  0.019977
#
# [198 rows x 14 columns]

# %%
new_df.to_csv('./data/poly_sang_200.csv', index = False)

# %%
a = list()
for col in data_df.columns:
    y = data_df[col].values
    x = np.array(list(data_df.index), dtype = float)
    xnew = np.arange(0,99, 0.25)
    f_quadr = interpolate.interp1d(x, y, kind='quadratic')
    y_new_quadr = f_quadr(xnew)
    a.append([y_new_quadr])
new_df = pd.DataFrame(np.concatenate(a).T, columns = data_df.columns)

# %%
new_df
# Out:
#       SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0   -0.346184 -0.528339 -0.863465 -0.617428 -0.106392  0.050823 -0.198278
# 1   -0.294311 -0.559352 -0.872298 -0.249072 -0.063150  0.112593 -0.114981
# 2   -0.244828 -0.548464 -0.791906  0.011113 -0.029934  0.157138 -0.046761
# 3   -0.197734 -0.495673 -0.622287  0.163127 -0.006743  0.184457  0.006382
# 4   -0.153031 -0.400980 -0.363443  0.206970  0.006421  0.194551  0.044448
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  0.097504  0.208624  0.541700  0.367966  0.143996  0.037948  0.158254
# 392  0.094404  0.150532  0.557996  0.537552  0.197651  0.060792  0.185354
# 393  0.077250  0.124079  0.529084  0.539591  0.204577  0.063736  0.161404
# 394  0.046044  0.129264  0.454964  0.374083  0.164774  0.046780  0.086404
# 395  0.000784  0.166088  0.335636  0.041027  0.078242  0.009924 -0.039647
#
#        NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0    0.045205  0.037551 -0.001210  0.104539 -0.038003  0.499180  0.251336
# 1    0.043084  0.038904 -0.147518  0.083279 -0.020361  0.345077  0.055808
# 2    0.035407  0.033537 -0.245564  0.059306 -0.006623  0.209089 -0.090979
# 3    0.022173  0.021450 -0.295349  0.032619  0.003211  0.091218 -0.189022
# 4    0.003382  0.002642 -0.296872  0.003218  0.009141 -0.008537 -0.238323
# ..        ...       ...       ...       ...       ...       ...       ...
# 391  0.166574  0.059247 -0.238152  0.033610 -0.018223  0.065742  0.175603
# 392  0.184256  0.102725 -0.275379  0.018454 -0.020639  0.016230  0.178246
# 393  0.160863  0.143770 -0.296615 -0.009948 -0.025852 -0.036088  0.126371
# 394  0.096395  0.182383 -0.301857 -0.051596 -0.033862 -0.091213  0.019977
# 395 -0.009147  0.218564 -0.291108 -0.106491 -0.044669 -0.149145 -0.140935
#
# [396 rows x 14 columns]

# %%
new_df.to_csv('./data/poly_sang_400.csv', index = False)

# %%
a = list()
for col in data_df.columns:
    y = data_df[col].values
    x = np.array(list(data_df.index), dtype = float)
    xnew = np.arange(0,99, 0.1)
    f_quadr = interpolate.interp1d(x, y, kind='quadratic')
    y_new_quadr = f_quadr(xnew)
    a.append([y_new_quadr])
new_df = pd.DataFrame(np.concatenate(a).T, columns = data_df.columns)
new_df
# Out:
#       SproutN    BunchN    GrapeW     WoodW    SPAD06    NDVI06    SPAD08  \
# 0   -0.346184 -0.528339 -0.863465 -0.617428 -0.106392  0.050823 -0.198278
# 1   -0.325148 -0.545773 -0.877705 -0.457105 -0.087892  0.077598 -0.163150
# 2   -0.304494 -0.556502 -0.877670 -0.314089 -0.070996  0.101617 -0.130435
# 3   -0.284223 -0.560527 -0.863358 -0.188381 -0.055705  0.122880 -0.100131
# 4   -0.264334 -0.557847 -0.834770 -0.079980 -0.042017  0.141387 -0.072240
# ..        ...       ...       ...       ...       ...       ...       ...
# 985  0.046044  0.129264  0.454964  0.374083  0.164774  0.046780  0.086404
# 986  0.029626  0.140197  0.412658  0.260966  0.135768  0.034426  0.042109
# 987  0.010960  0.156192  0.363119  0.121042  0.099286  0.018887 -0.010353
# 988 -0.009954  0.177249  0.306346 -0.045690  0.055328  0.000165 -0.070983
# 989 -0.033117  0.203369  0.242340 -0.239229  0.003893 -0.021741 -0.139781
#
#        NDVI08      Acid    Potass      Brix        pH    Anthoc    Polyph
# 0    0.045205  0.037551 -0.001210  0.104539 -0.038003  0.499180  0.251336
# 1    0.045023  0.038899 -0.065524  0.096361 -0.030477  0.435365  0.167276
# 2    0.043953  0.039171 -0.122117  0.087748 -0.023577  0.374448  0.091014
# 3    0.041994  0.038369 -0.170988  0.078702 -0.017301  0.316430  0.022551
# 4    0.039145  0.036491 -0.212137  0.069221 -0.011650  0.261311 -0.038113
# ..        ...       ...       ...       ...       ...       ...       ...
# 985  0.096395  0.182383 -0.301857 -0.051596 -0.033862 -0.091213  0.019977
# 986  0.059107  0.197147 -0.299477 -0.071965 -0.037849 -0.114049 -0.037845
# 987  0.015247  0.211523 -0.294537 -0.094453 -0.042284 -0.137334 -0.104391
# 988 -0.035185  0.225509 -0.287039 -0.119060 -0.047167 -0.161068 -0.179659
# 989 -0.092188  0.239106 -0.276982 -0.145787 -0.052496 -0.185251 -0.263651
#
# [990 rows x 14 columns]

# %%
new_df.to_csv('./data/poly_sang_1000.csv', index = False)
